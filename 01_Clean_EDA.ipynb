# %% [markdown]
# ### Initial EDA and Linear Regression Viability
# - Data clean up, remove outliers
# - Apply inflation to Gross and Budget

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
import re
import cpi
from datetime import datetime
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/cpi/__init__.py:46: StaleDataWarning: CPI data is out of date. To accurately inflate to today's dollars, you must run `cpi.update()`.
#   warnings.warn(StaleDataWarning())

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#bring data together
batch1 = pd.read_csv('/Users/jennihawk/Desktop/Thriller Project/Movie_Linear_Regression/thriller_csv_files/thrillers_1_to_350_year_budget.csv')
batch2 = pd.read_csv('/Users/jennihawk/Desktop/Thriller Project/Movie_Linear_Regression/thriller_csv_files/thrillers_351_700rows.csv')
batch3 = pd.read_csv('/Users/jennihawk/Desktop/Thriller Project/Movie_Linear_Regression/thriller_csv_files/thrillers_751_1150rows.csv')

all_movies = [batch1, batch2, batch3]

movie_df = pd.concat(all_movies)

# %%
movie_df.reset_index(drop=True, inplace=True)

# %%
#movie_df

# %% [markdown]
# #### Replace current budget column with new, updated column values

# %%
all_budget = pd.read_csv('/Users/jennihawk/Desktop/Thriller Project/Movie_Linear_Regression/thriller_csv_files/all_data_budgetcol_only.csv')

# %%
all_budget.head()
# Out:
#                              Title       Budget
# 0                  The Dark Knight  185000000.0
# 1  The Hunger Games: Catching Fire  130000000.0
# 2                 The Hunger Games   78000000.0
# 3                    Jurassic Park   63000000.0
# 4                        Furious 7  190000000.0

# %%
# bring in new budget column from all_budget df
movie_df = pd.merge(movie_df, all_budget, on="Title")
movie_df.head()
# Out:
#                              Title Duration                      Genre Rating  \
# 0                  The Dark Knight  152 min       Action, Crime, Drama  PG-13
# 1  The Hunger Games: Catching Fire  146 min   Action, Adventure, Drama  PG-13
# 2                 The Hunger Games  142 min  Action, Adventure, Sci-Fi  PG-13
# 3                    Jurassic Park  127 min  Action, Adventure, Sci-Fi  PG-13
# 4                        Furious 7  137 min    Action, Crime, Thriller  PG-13
#
#     Gross           Director               Lead     Budget_x  Year  \
# 0  534.86  Christopher Nolan     Christian Bale  185000000.0  2008
# 1  424.67   Francis Lawrence  Jennifer Lawrence  130000000.0  2013
# 2  408.01          Gary Ross  Jennifer Lawrence   78000000.0  2012
# 3  402.45   Steven Spielberg          Sam Neill   63000000.0  1993
# 4  353.01          James Wan         Vin Diesel  190000000.0  2015
#
#       Budget_y
# 0  185000000.0
# 1  130000000.0
# 2   78000000.0
# 3   63000000.0
# 4  190000000.0

# %%
#remove old budget column
movie_df.drop(['Budget_x'], axis=1, inplace=True)
movie_df.head()
# Out:
#                              Title Duration                      Genre Rating  \
# 0                  The Dark Knight  152 min       Action, Crime, Drama  PG-13
# 1  The Hunger Games: Catching Fire  146 min   Action, Adventure, Drama  PG-13
# 2                 The Hunger Games  142 min  Action, Adventure, Sci-Fi  PG-13
# 3                    Jurassic Park  127 min  Action, Adventure, Sci-Fi  PG-13
# 4                        Furious 7  137 min    Action, Crime, Thriller  PG-13
#
#     Gross           Director               Lead  Year     Budget_y
# 0  534.86  Christopher Nolan     Christian Bale  2008  185000000.0
# 1  424.67   Francis Lawrence  Jennifer Lawrence  2013  130000000.0
# 2  408.01          Gary Ross  Jennifer Lawrence  2012   78000000.0
# 3  402.45   Steven Spielberg          Sam Neill  1993   63000000.0
# 4  353.01          James Wan         Vin Diesel  2015  190000000.0

# %%
#rename 'budget_y' to 'budget'
movie_df.rename(columns = {'Budget_y':'Budget_Update'}, inplace = True)
movie_df.head()
# Out:
#                              Title Duration                      Genre Rating  \
# 0                  The Dark Knight  152 min       Action, Crime, Drama  PG-13
# 1  The Hunger Games: Catching Fire  146 min   Action, Adventure, Drama  PG-13
# 2                 The Hunger Games  142 min  Action, Adventure, Sci-Fi  PG-13
# 3                    Jurassic Park  127 min  Action, Adventure, Sci-Fi  PG-13
# 4                        Furious 7  137 min    Action, Crime, Thriller  PG-13
#
#     Gross           Director               Lead  Year  Budget_Update
# 0  534.86  Christopher Nolan     Christian Bale  2008    185000000.0
# 1  424.67   Francis Lawrence  Jennifer Lawrence  2013    130000000.0
# 2  408.01          Gary Ross  Jennifer Lawrence  2012     78000000.0
# 3  402.45   Steven Spielberg          Sam Neill  1993     63000000.0
# 4  353.01          James Wan         Vin Diesel  2015    190000000.0

# %%
movie_df.columns
# Out:
# Index(['Title', 'Duration', 'Genre', 'Rating', 'Gross', 'Director', 'Lead',
#        'Year', 'Budget_Update'],
#       dtype='object')

# %%
#27 missing budget values
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1121 entries, 0 to 1120
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          1121 non-null   object
#  1   Duration       1121 non-null   object
#  2   Genre          1121 non-null   object
#  3   Rating         1121 non-null   object
#  4   Gross          1121 non-null   float64
#  5   Director       1121 non-null   object
#  6   Lead           1121 non-null   object
#  7   Year           1121 non-null   object
#  8   Budget_Update  1094 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 87.6+ KB

# %%
# shows rows that have null values
movie_df[movie_df.isnull().any(axis=1)]
# Out:
#                                                 Title Duration  \
# 73                              A Quiet Place Part II   97 min
# 421   Temptation: Confessions of a Marriage Counselor  111 min
# 435                                     Jai Lava Kusa  150 min
# 665                                  Sharky's Machine  122 min
# 728                                      Blade Runner  117 min
# 757                                                 9   79 min
# 809                                          Deceived  104 min
# 823                                    That Darn Cat!  116 min
# 865                                          Æon Flux   93 min
# 887                The VVitch: A New-England Folktale   92 min
# 901                        The Other Side of Midnight  165 min
# 911                                        Iron Eagle  117 min
# 959                                          Ricochet  102 min
# 960                                   Shining Through  132 min
# 974                                        Waist Deep   97 min
# 995                                              Fear   97 min
# 1019                                   A Force of One   90 min
# 1024                                     The Presidio   97 min
# 1028                                   Altered States  102 min
# 1041                                              Joe  107 min
# 1051                                           Sniper   98 min
# 1055                                 The Seventh Sign   97 min
# 1085                            The Day of the Locust  144 min
# 1096                                Eye of the Needle  112 min
# 1102                                         Lassiter  100 min
# 1110                              Murder in the First  122 min
# 1120                                       Diabolique  107 min
#
#                              Genre     Rating   Gross             Director  \
# 73           Drama, Horror, Sci-Fi      PG-13  160.07       John Krasinski
# 421       Drama, Romance, Thriller      PG-13   51.98          Tyler Perry
# 435        Action, Drama, Thriller  Not Rated   51.00        K.S. Ravindra
# 665           Action, Crime, Drama          R   35.61        Burt Reynolds
# 728          Action, Drama, Sci-Fi          R   32.87         Ridley Scott
# 757   Animation, Action, Adventure      PG-13   31.74          Shane Acker
# 809          Crime, Drama, Mystery      PG-13   28.74        Damian Harris
# 823          Comedy, Crime, Family   Approved   28.06     Robert Stevenson
# 865      Action, Adventure, Sci-Fi      PG-13   25.86         Karyn Kusama
# 887        Drama, Fantasy, History          R   25.14        Robert Eggers
# 901       Drama, Romance, Thriller          R   24.65      Charles Jarrott
# 911          Action, Thriller, War      PG-13   24.16      Sidney J. Furie
# 959           Action, Crime, Drama          R   21.76      Russell Mulcahy
# 960       Drama, Romance, Thriller          R   21.73        David Seltzer
# 974           Action, Crime, Drama          R   21.32   Vondie Curtis-Hall
# 995                Drama, Thriller          R   20.75          James Foley
# 1019          Action, Crime, Drama         PG   20.17           Paul Aaron
# 1024        Action, Crime, Mystery          R   20.04          Peter Hyams
# 1028      Horror, Sci-Fi, Thriller          R   19.85          Ken Russell
# 1041               Drama, Thriller          R   19.32     John G. Avildsen
# 1051         Action, Thriller, War          R   18.99           Luis Llosa
# 1055        Drama, Fantasy, Horror          R   18.88         Carl Schultz
# 1085               Drama, Thriller          R   17.79     John Schlesinger
# 1096        Romance, Thriller, War          R   17.58     Richard Marquand
# 1102          Action, Crime, Drama          R   17.50          Roger Young
# 1110               Drama, Thriller          R   17.38           Marc Rocco
# 1120        Drama, Horror, Mystery          R   17.10  Jeremiah S. Chechik
#
#                      Lead    Year  Budget_Update
# 73            Emily Blunt    2020            NaN
# 421       Jurnee Smollett    2013            NaN
# 435     N.T. Rama Rao Jr.    2017            NaN
# 665         Burt Reynolds    1981            NaN
# 728         Harrison Ford    1982            NaN
# 757           Elijah Wood  I 2009            NaN
# 809           Goldie Hawn    1991            NaN
# 823          Hayley Mills    1965            NaN
# 865       Charlize Theron    2005            NaN
# 887       Anya Taylor-Joy    2015            NaN
# 901   Marie-France Pisier    1977            NaN
# 911     Louis Gossett Jr.    1986            NaN
# 959     Denzel Washington    1991            NaN
# 960       Michael Douglas    1992            NaN
# 974         Tyrese Gibson    2006            NaN
# 995         Mark Wahlberg    1996            NaN
# 1019     Jennifer O'Neill    1979            NaN
# 1024         Sean Connery    1988            NaN
# 1028         William Hurt    1980            NaN
# 1041          Peter Boyle    1970            NaN
# 1051         Tom Berenger    1993            NaN
# 1055           Demi Moore    1988            NaN
# 1085    Donald Sutherland    1975            NaN
# 1096    Donald Sutherland    1981            NaN
# 1102          Tom Selleck    1984            NaN
# 1110     Christian Slater    1995            NaN
# 1120         Sharon Stone    1996            NaN

# %%
#sum of rows with at least one missing data
total_miss = movie_df.isnull().any(axis=1).sum()
total_miss
# Out:
# 27

# %%
#drop the 27 nulls in budget column
movie_df.dropna(subset=['Budget_Update'], inplace=True)

# %%
# drop outlier The Curse of Frankenstein 1957
movie_df.drop(index = 1084, inplace = True)

# %%
#find original Jaws in 'Title' use 'contains' to find substring in column
find_jaws = movie_df.loc[movie_df['Title'].str.contains("Jaws", case=False)]
find_jaws
# Out:
#                  Title Duration                        Genre Rating   Gross  \
# 14                Jaws  124 min          Adventure, Thriller     PG  260.75
# 166             Jaws 2  116 min  Adventure, Horror, Thriller     PG  102.92
# 503           Jaws 3-D   99 min  Adventure, Horror, Thriller     PG   45.52
# 994  Jaws: The Revenge   89 min  Adventure, Horror, Thriller  PG-13   20.76
#
#              Director           Lead  Year  Budget_Update
# 14   Steven Spielberg   Roy Scheider  1975      7000000.0
# 166    Jeannot Szwarc   Roy Scheider  1978     20000000.0
# 503         Joe Alves   Dennis Quaid  1983     20500000.0
# 994    Joseph Sargent  Lorraine Gary  1987     23000000.0

# %%
# drop outlier Jaws 1975 - Jaws is a complete unique phenomenon that would distort charts
movie_df.drop(index = 14, inplace = True)

# %% [markdown]
# #### Clean up

# %%
#remove any leading/trailing in column titles
movie_df.columns = movie_df.columns.map(str.strip)
#movie_df

# %%
# Duration cleanup + change to float
movie_df['Duration'] = movie_df['Duration'].str.replace('min', '').astype(float)

# %%
movie_df['Budget_Update'] = movie_df['Budget_Update'].astype(float)

# %%
pd.set_option('display.max_rows', None)

# %%
# Cast year as string to remove extra chars in front of some columns year
movie_df['Year'] = movie_df['Year'].astype(str)

# %%
movie_df['Duration'] = movie_df['Duration'].astype(int)

# %%
movie_df.head()
# Out:
#                              Title  Duration                      Genre  \
# 0                  The Dark Knight       152       Action, Crime, Drama
# 1  The Hunger Games: Catching Fire       146   Action, Adventure, Drama
# 2                 The Hunger Games       142  Action, Adventure, Sci-Fi
# 3                    Jurassic Park       127  Action, Adventure, Sci-Fi
# 4                        Furious 7       137    Action, Crime, Thriller
#
#   Rating   Gross           Director               Lead  Year  Budget_Update
# 0  PG-13  534.86  Christopher Nolan     Christian Bale  2008    185000000.0
# 1  PG-13  424.67   Francis Lawrence  Jennifer Lawrence  2013    130000000.0
# 2  PG-13  408.01          Gary Ross  Jennifer Lawrence  2012     78000000.0
# 3  PG-13  402.45   Steven Spielberg          Sam Neill  1993     63000000.0
# 4  PG-13  353.01          James Wan         Vin Diesel  2015    190000000.0

# %%
#make 'Gross' same distribution as 'Budget'
movie_df['Gross'] = movie_df['Gross'].apply(lambda x: x * 1000000)

# %%
movie_df.head()
# Out:
#                              Title  Duration                      Genre  \
# 0                  The Dark Knight       152       Action, Crime, Drama
# 1  The Hunger Games: Catching Fire       146   Action, Adventure, Drama
# 2                 The Hunger Games       142  Action, Adventure, Sci-Fi
# 3                    Jurassic Park       127  Action, Adventure, Sci-Fi
# 4                        Furious 7       137    Action, Crime, Thriller
#
#   Rating        Gross           Director               Lead  Year  \
# 0  PG-13  534860000.0  Christopher Nolan     Christian Bale  2008
# 1  PG-13  424670000.0   Francis Lawrence  Jennifer Lawrence  2013
# 2  PG-13  408010000.0          Gary Ross  Jennifer Lawrence  2012
# 3  PG-13  402450000.0   Steven Spielberg          Sam Neill  1993
# 4  PG-13  353010000.0          James Wan         Vin Diesel  2015
#
#    Budget_Update
# 0    185000000.0
# 1    130000000.0
# 2     78000000.0
# 3     63000000.0
# 4    190000000.0

# %% [markdown]
# #### Clean up extra chars in year

# %%
# remove extra chars in year column
def my_function(x):
    return x[-4:]
#saves over the column
movie_df['Year'] = movie_df['Year'].map(my_function)

# %% [markdown]
# #### Inflation work
# https://pypi.org/project/cpi/

# %%
movie_df['Year']=pd.to_datetime(movie_df['Year'], format='%Y')

# %%
movie_df['Year'] = movie_df['Year'].dt.year

# %%
movie_df['Budget_Adjust'] = movie_df.apply(lambda x: cpi.inflate(x.Budget_Update, x.Year), axis=1)

# %%
movie_df['Budget_Adjust'] = movie_df['Budget_Adjust'].round(decimals = 1)

# %%
movie_df['Gross_Adjust'] = movie_df.apply(lambda x: cpi.inflate(x.Gross, x.Year), axis=1)

# %%
movie_df['Gross_Adjust'] = movie_df['Gross_Adjust'].round(decimals = 1)

# %%
movie_df.head(3)
# Out:
#                              Title  Duration                      Genre  \
# 0                  The Dark Knight       152       Action, Crime, Drama
# 1  The Hunger Games: Catching Fire       146   Action, Adventure, Drama
# 2                 The Hunger Games       142  Action, Adventure, Sci-Fi
#
#   Rating        Gross           Director               Lead  Year  \
# 0  PG-13  534860000.0  Christopher Nolan     Christian Bale  2008
# 1  PG-13  424670000.0   Francis Lawrence  Jennifer Lawrence  2013
# 2  PG-13  408010000.0          Gary Ross  Jennifer Lawrence  2012
#
#    Budget_Update  Budget_Adjust  Gross_Adjust
# 0    185000000.0    232832101.7   673149069.9
# 1    130000000.0    151212884.8   493965967.5
# 2     78000000.0     92056674.0   481539019.7

# %%
#spot check 
# test = cpi.inflate(250000000, 2017, to=2021)
# test

# %% [markdown]
# #### Drop ratings except PG-13, PG, R

# %%
movie_df.Rating.value_counts()
# Out:
# R            630
# PG-13        383
# PG            72
# Not Rated      2
# Approved       2
# G              1
# M/PG           1
# X              1
# Name: Rating, dtype: int64

# %%
movie_df.drop(movie_df.index[movie_df['Rating'] == 'Not Rated'], inplace=True)

# %%
movie_df.drop(movie_df.index[movie_df['Rating'] == 'Approved'], inplace=True)
movie_df.drop(movie_df.index[movie_df['Rating'] == 'G'], inplace=True)
movie_df.drop(movie_df.index[movie_df['Rating'] == 'M/PG'], inplace=True)
movie_df.drop(movie_df.index[movie_df['Rating'] == 'X'], inplace=True)

# %%
movie_df.Rating.value_counts()
# Out:
# R        630
# PG-13    383
# PG        72
# Name: Rating, dtype: int64

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1119
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          1085 non-null   object
#  1   Duration       1085 non-null   int64
#  2   Genre          1085 non-null   object
#  3   Rating         1085 non-null   object
#  4   Gross          1085 non-null   float64
#  5   Director       1085 non-null   object
#  6   Lead           1085 non-null   object
#  7   Year           1085 non-null   int64
#  8   Budget_Update  1085 non-null   float64
#  9   Budget_Adjust  1085 non-null   float64
#  10  Gross_Adjust   1085 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 101.7+ KB

# %%
#movie_df.to_csv('movies_cleaned.csv', index=False)
